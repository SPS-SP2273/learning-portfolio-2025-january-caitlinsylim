# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need) Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %%
# Some data for plotting
import matplotlib.pyplot as plt
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, 
             xerr=x_err, yerr=y_err,
             color='maroon', linestyle='dashed',
             marker='o', markerfacecolor='yellow',
             ecolor='black',capsize=5,
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 2

# %%
import matplotlib.pyplot as plt

x = np.linspace(0, 50, 1000)

y = np.exp(-x/10) * np.sin(x)

plt.plot(x, y)

plt.xlabel('x', fontsize = 15, color = 'darkorange')
plt.ylabel('y', fontsize = 15, rotation = 0, color = 'darkorange')
plt.grid(alpha=.25)
plt.title('$y = e^{-x/10}\\sin (x)$',fontsize = 20)
plt.ylim([-1, 1])
# Out:
# (-1.0, 1.0)

# %%
y_array = np.exp(-x/10) * np.sin(x)

print(y_array)
# Out:
# [ 0.00000000e+00  1.76572193e-02 -3.32867824e-01  2.17332551e-04
#  -8.21522155e-02 -8.21522155e-02  1.04544273e-01 -1.59105321e-02
#  -5.81616973e-01 -6.32254153e-03 -8.48410793e-02 -8.48410793e-02
#   1.02453861e-01 -5.07299883e-01  2.24773669e-02  3.26249890e-01
#   1.02453861e-01 -4.91911980e-02  1.14508876e-01  9.06462835e-03
#  -1.37437693e-02  0.00000000e+00 -2.62880200e-03 -8.48410793e-02
#   1.02453861e-01  1.95090609e-02  1.95090609e-02  6.42737346e-02
#  -1.08640932e-02 -9.80753025e-04 -1.82015737e-02  1.76572193e-02
#   2.24773669e-02 -3.65152732e-02 -7.10219836e-03  1.23553704e-01
#   6.62999386e-03 -1.29299962e-02 -5.81266772e-02 -8.21522155e-02
#   6.42737346e-02  7.44469767e-01  1.95090609e-02 -1.29299962e-02
#  -6.32254153e-03  1.95090609e-02  6.42737346e-02  1.76572193e-02
#   9.45268431e-03  2.44280766e-01]

# %%
x_graph = x_array
y_graph = y_array

plt.plot(x_graph, y_graph, 
             color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim([-1,1])
plt.title('$e^{-x/10}\sin x$')
plt.grid(alpha=.25)
plt.show()
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/q3/4xm0rfy56rl5wc7lh6dwp_6r0000gq/T/ipykernel_87378/3320460254.py:9: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('$e^{-x/10}\sin x$')
