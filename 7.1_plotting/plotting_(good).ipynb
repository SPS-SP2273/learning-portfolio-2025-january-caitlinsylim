# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 2 Comparing the two ‘dialects’

# %%
from matplotlib import pyplot as plt 
import numpy as np

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %% [markdown]
# Comparing the codes:
# - There are small differences
# - First graph & 2nd graph: only difference is instead of plt, you use ax
# - You create a figure and axis

# %%
plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,3), sharex='col', sharey='row')  # sharex and sharey to share x & y axis to compare data easily

my_cos, my_sin, my_gcos, my_gsin = ax.flatten()            

ax[0,0].plot(x, cos_x, label='cos x', color='red', linestyle='--')              

ax[0,1].plot(x, sin_x, label='sin x')

ax[1,0].plot(x, cos_x, label='cos x', color='green', linestyle='--')

ax[1,1].plot(x, sin_x, label='sin x', color='green')

ax[0,0].set_xlabel('Hahaha')

for axis in ax.flatten():                   
    axis.legend()                   
    axis.grid()

my_gcos.set_title('Whooo')

plt.tight_layout()           # Magic command to make your plot nicer

# %% [markdown]
# # 3 What is OO ax, really?

# %% [markdown]
# #### Using Ax

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,3)) 

ax[0,0].plot(x, cos_x, label='cos x', color='red', linestyle='--')              

ax[0,1].plot(x, sin_x, label='sin x')

ax[1,0].plot(x, cos_x, label='cos x', color='green', linestyle='--')

ax[1,1].plot(x, sin_x, label='sin x', color='green')

ax[0,0].set_xlabel('Hahaha')

for axis in ax:                     # This shows error because I have 2x2 dimension, but the for loop is for lists here. So I need to flatten
    axis.legend()                   # By flattening it, I can make it 1D. See below:
    axis.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 14
#      11 ax[0,0].set_xlabel('Hahaha')
#      13 for axis in ax:                     # This shows error because I have 2x2 dimension, but the for loop is for lists here. So I need to flatten
# ---> 14     axis.legend()                   # By flattening it, I can make it 1D. See below:
#      15     axis.grid()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'legend'

# %%
ax.flatten()                 # I have flattened it here, 1D here as there is only 1x []
# Out:
# array([<Axes: xlabel='Hahaha'>, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
ax                             # It is 2D 2x2 here, there are 2x []
# Out:
# array([[<Axes: xlabel='Hahaha'>, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# # 5 Multiple rows and columns

# %% [markdown]
# What if I want to add gridlines to it?
# - I will need to include ax[0].grid(alpha=.25) for both sinx and cosx
# - But this is repetitive, I don't want it
# - I can use a for loop!

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,3))          
ax[0].plot(x, cos_x, label='cos x', color='red', linestyle='--')              
# ax[0].legend()
ax[1].plot(x, sin_x, label='sin x')
# ax[1].legend()
ax[0].set_xlabel('Hahaha')

for axis in ax: 
    axis.legend()
    axis.grid()

# %%
ax        # There are 2 becos I created 2
# Out:
# array([<Axes: xlabel='Hahaha'>, <Axes: >], dtype=object)

# %% [markdown]
# What if I create more? Eg making it 2x2

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,3))          
ax[0].plot(x, cos_x, label='cos x', color='red', linestyle='--')              
# ax[0].legend()
ax[1].plot(x, sin_x, label='sin x')
# ax[1].legend()
ax[0].set_xlabel('Hahaha')

for axis in ax: 
    axis.legend()
    axis.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,3))
# ----> 2 ax[0].plot(x, cos_x, label='cos x', color='red', linestyle='--')
#       3 # ax[0].legend()
#       4 ax[1].plot(x, sin_x, label='sin x')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %% [markdown]
# I have an error here
# - Because I keyed nrows=2, ncols=2 -> asking for 4 subplots to give me 2 x 2 array
# - fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,3))  --> ax has 4 elements in it

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)          # Creating figure and axis 
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)          # Creating 2 different axis
ax[0].plot(x, cos_x, label='cos x', color='red', linestyle='--')               # Default is blue, if I want to make it red, change
ax[0].legend()
ax[1].plot(x, sin_x, label='sin x')
ax[1].legend()
ax[0].set_xlabel('Hahaha')               # Setting your X axis
# Out:
# Text(0.5, 0, 'Hahaha')

# %% [markdown]
# You can adjust your figure size also

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,3))          # figsize comes in inches
ax[0].plot(x, cos_x, label='cos x', color='red', linestyle='--')               # Default is blue, if I want to make it red, change
ax[0].legend()
ax[1].plot(x, sin_x, label='sin x')
ax[1].legend()
ax[0].set_xlabel('Hahaha')
# Out:
# Text(0.5, 0, 'Hahaha')

# %% [markdown]
# ## 5.1 Sharing axes

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,3), sharex='col', sharey='row')  # sharex and sharey to share x & y axis to compare data easily

my_cos, my_sin, my_gcos, my_gsin = ax.flatten()            

ax[0,0].plot(x, cos_x, label='cos x', color='red', linestyle='--')              

ax[0,1].plot(x, sin_x, label='sin x')

ax[1,0].plot(x, cos_x, label='cos x', color='green', linestyle='--')

ax[1,1].plot(x, sin_x, label='sin x', color='green')

ax[0,0].set_xlabel('Hahaha')

for axis in ax.flatten():                   
    axis.legend()                   
    axis.grid()

my_gcos.set_title('Whooo')

plt.tight_layout()

# %% [markdown]
# ## 5.2 Accessing all axes

# %% [markdown]
# # 6 Other useful plots

# %% [markdown]
# ## 6.2 Scatter plots

# %% [markdown]
# ## 6.3 Bar charts

# %% [markdown]
# ## 6.4 Pie charts
